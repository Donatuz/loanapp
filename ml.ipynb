# %% [markdown]
# ## Machine Learning

# %%
Supervised machine learning, It works on label data.
    Supervised machine learning is divided into
1. Classification ML-- It predicts discrete values or class.(Yes/No, True/False)
    logistics, random forest, support vector machine, XGboost

2. Regression ML -- It predicts continous values, salary, age, price
linear regression, lasso regression, support vector regressor

Unsupervised machine learning,

# %%
x = ['Spain', 'Germany', 'Nigeria']

# %%
z = pd.DataFrame(x)

# %%
z
# Out:
#          0
# 0    Spain
# 1  Germany
# 2  Nigeria

# %%
spain =   0, 1
Nigeria = 1, 0

# %%
targetcolumn

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\DONATUS\Desktop\school\skillAhead\B4\bankloan.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0           0  LP001002   Male      No          0      Graduate            No
# 1           1  LP001003   Male     Yes          1      Graduate            No
# 2           2  LP001005   Male     Yes          0      Graduate           Yes
# 3           3  LP001006   Male     Yes          0  Not Graduate            No
# 4           4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# ...

# %%
# label functions

# %%
 from sklearn.preprocessing import LabelEncoder #labelEncoder function

# %%
#loading the label encoder function
 #It labels with values between 0 and 1
l_encoder = LabelEncoder()

# %%
 #transforming values of Bank loan to 0 nad 1
 df['Loan_Status'] = label_encoder.fit_transform(df.Loan_Status)

# %%
df.head()
# Out:
#    Unnamed: 0   Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0           0  LP001002   Male      No          0      Graduate            No
# 1           1  LP001003   Male     Yes          1      Graduate            No
# 2           2  LP001005   Male     Yes          0      Graduate           Yes
# 3           3  LP001006   Male     Yes          0  Not Graduate            No
# 4           4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area  Loan_Status
# ...

# %% [markdown]
# ## Machine Learning

# %%
Supervised machine learning, It works on label data.
    Supervised machine learning is divided into
1. Classification ML-- It predicts discrete values or class.(Yes/No, True/False)
    logistics, random forest, support vector machine, XGboost

2. Regression ML -- It predicts continous values, salary, age, price
linear regression, lasso regression, support vector regressor

Unsupervised machine learning,

# %%
x = ['Spain', 'Germany', 'Nigeria']

# %%
z = pd.DataFrame(x)

# %%
z
# Out:
#          0
# 0    Spain
# 1  Germany
# 2  Nigeria

# %%
spain =   0, 1
Nigeria = 1, 0

# %%
targetcolumn

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\DONATUS\Desktop\school\skillAhead\B4\bankloan.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0           0  LP001002   Male      No          0      Graduate            No
# 1           1  LP001003   Male     Yes          1      Graduate            No
# 2           2  LP001005   Male     Yes          0      Graduate           Yes
# 3           3  LP001006   Male     Yes          0  Not Graduate            No
# 4           4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# ...

# %%
# label functions

# %%
 from sklearn.preprocessing import LabelEncoder #labelEncoder function

# %%
#loading the label encoder function
 #It labels with values between 0 and 1
l_encoder = LabelEncoder()

# %%
 #transforming values of Bank loan to 0 nad 1
 df['Loan_Status'] = label_encoder.fit_transform(df.Loan_Status)

# %%
df.head()
# Out:
#    Unnamed: 0   Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0           0  LP001002   Male      No          0      Graduate            No
# 1           1  LP001003   Male     Yes          1      Graduate            No
# 2           2  LP001005   Male     Yes          0      Graduate           Yes
# 3           3  LP001006   Male     Yes          0  Not Graduate            No
# 4           4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area  Loan_Status
# ...

# %% [markdown]
# ## Machine Learning

# %%
Supervised machine learning, It works on label data.
    Supervised machine learning is divided into
1. Classification ML-- It predicts discrete values or class.(Yes/No, True/False)
    logistics, random forest, support vector machine, XGboost

2. Regression ML -- It predicts continous values, salary, age, price
linear regression, lasso regression, support vector regressor

Unsupervised machine learning,

# %%
x = ['Spain', 'Germany', 'Nigeria']

# %%
z = pd.DataFrame(x)

# %%
z
# Out:
#          0
# 0    Spain
# 1  Germany
# 2  Nigeria

# %%
spain =   0, 1
Nigeria = 1, 0

# %%
targetcolumn

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\DONATUS\Desktop\school\skillAhead\B4\bankloan.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0           0  LP001002   Male      No          0      Graduate            No
# 1           1  LP001003   Male     Yes          1      Graduate            No
# 2           2  LP001005   Male     Yes          0      Graduate           Yes
# 3           3  LP001006   Male     Yes          0  Not Graduate            No
# 4           4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# ...

# %%
# label functions

# %%
 from sklearn.preprocessing import LabelEncoder #labelEncoder function

# %%
#loading the label encoder function
 #It labels with values between 0 and 1
l_encoder = LabelEncoder()

# %%
 #transforming values of Bank loan to 0 nad 1
 df['Loan_Status'] = label_encoder.fit_transform(df.Loan_Status)

# %%
df.head()
# Out:
#    Unnamed: 0   Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0           0  LP001002   Male      No          0      Graduate            No
# 1           1  LP001003   Male     Yes          1      Graduate            No
# 2           2  LP001005   Male     Yes          0      Graduate           Yes
# 3           3  LP001006   Male     Yes          0  Not Graduate            No
# 4           4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area  Loan_Status
# ...

# %% [markdown]
# ## Machine Learning

# %%
Supervised machine learning, It works on label data.
    Supervised machine learning is divided into
1. Classification ML-- It predicts discrete values or class.(Yes/No, True/False)
    logistics, random forest, support vector machine, XGboost

2. Regression ML -- It predicts continous values, salary, age, price
linear regression, lasso regression, support vector regressor

Unsupervised machine learning,

# %%
x = ['Spain', 'Germany', 'Nigeria']

# %%
z = pd.DataFrame(x)

# %%
z
# Out:
#          0
# 0    Spain
# 1  Germany
# 2  Nigeria

# %%
spain =   0, 1
Nigeria = 1, 0

# %%
targetcolumn

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\DONATUS\Desktop\school\skillAhead\B4\bankloan.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0           0  LP001002   Male      No          0      Graduate            No
# 1           1  LP001003   Male     Yes          1      Graduate            No
# 2           2  LP001005   Male     Yes          0      Graduate           Yes
# 3           3  LP001006   Male     Yes          0  Not Graduate            No
# 4           4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# ...

# %%
# label functions

# %%
 from sklearn.preprocessing import LabelEncoder #labelEncoder function

# %%
#loading the label encoder function
 #It labels with values between 0 and 1
l_encoder = LabelEncoder()

# %%
 #transforming values of Bank loan to 0 nad 1
 df['Loan_Status'] = label_encoder.fit_transform(df.Loan_Status)

# %%
df.head()
# Out:
#    Unnamed: 0   Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0           0  LP001002   Male      No          0      Graduate            No
# 1           1  LP001003   Male     Yes          1      Graduate            No
# 2           2  LP001005   Male     Yes          0      Graduate           Yes
# 3           3  LP001006   Male     Yes          0  Not Graduate            No
# 4           4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area  Loan_Status
# ...
